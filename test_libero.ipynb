# %%
from experiments.robot.libero.run_libero_eval import eval_libero,GenerateConfig

# %%
cfg = GenerateConfig()
# cfg.model_id ="/mnt/project_rlinf/jlchen/code/UniVLA/vla_scripts/world_vla_log/0114_165156+weights+libero+lr-0.0001+frzVis+frzLLM+unfrzLast4+frzEmb--finetune_libero_simple/checkpoints/step-040000"
# cfg.model_id = "/mnt/project_rlinf/jlchen/code/UniVLA/vla_scripts/world_vla_log/0121_174817+checkpoints+libero_all+lr-1e-05+frzVis+frzLLM+unfrzLast4+frzEmb--finetune_libero_all_wrist/checkpoints/step-015000"
# cfg.model_id = "/mnt/project_rlinf/jlchen/code/UniVLA/vla_scripts/world_vla_log/0123_154819+checkpoints+libero_object_no_noops+lr-0.0001+frzVis+frzLLM+unfrzLast4+frzEmb--finetune_libero_all_inter/checkpoints/step-015000"
cfg.model_id = "/mnt/project_rlinf/jlchen/code/UniVLA/vla_scripts/world_vla_log/0130_004311+libero4in1--vldit/checkpoints/step-100000"
# cfg.use_simple_model = False
# cfg.use_history_frame = True
# cfg.num_actions_to_use = 10
# cfg.future_prediction = True
# cfg.enable_wrist_view = True
# cfg.save_similarity_video = True
cfg.task_suite_name = "libero_object"          # Task suite. Options: libero_spatial, libero_object, libero_goal, libero_10, libero_90
cfg.num_trials_per_task = 50
cfg.num_inference_steps = 30
cfg.save_video = False
cfg.save_fail_video = True
eval_libero.__wrapped__(cfg)
