# %%
from experiments.robot.libero.run_libero_eval import eval_libero,GenerateConfig
# Out:
# 2026-01-21 15:37:05.848101: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-21 15:37:05.892718: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-21 15:37:05.892758: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-21 15:37:05.894394: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
cfg = GenerateConfig()
# cfg.model_id ="/mnt/project_rlinf/jlchen/code/UniVLA/vla_scripts/world_vla_log/0114_165156+weights+libero+lr-0.0001+frzVis+frzLLM+unfrzLast4+frzEmb--finetune_libero_simple/checkpoints/step-040000"
cfg.model_id = "/mnt/project_rlinf/jlchen/code/UniVLA/vla_scripts/world_vla_log/0121_121439+checkpoints+libero_object_no_noops+lr-0.0001+frzVis+frzLLM+unfrzLast4+frzEmb--finetune_libero_all_no_future_no_hist/checkpoints/step-005000"
cfg.use_simple_model = False
cfg.use_history_frame = False
cfg.num_actions_to_use = 10
cfg.future_prediction = False
eval_libero.__wrapped__(cfg)
# Out:
# [*] Auto-derived dataset_statistics_path: /mnt/project_rlinf/jlchen/code/UniVLA/vla_scripts/world_vla_log/0121_121439+checkpoints+libero_object_no_noops+lr-0.0001+frzVis+frzLLM+unfrzLast4+frzEmb--finetune_libero_all_no_future_no_hist/dataset_statistics.json
# [*] Loading LatentWorldVLA model...
# 01/21 [15:37:27] INFO     | >> 🔄 加载基础 VLM                                              ]8;id=75954;file:///mnt/project_rlinf/jlchen/code/UniVLA/prismatic/vla/latent_vla_model.py\latent_vla_model.py]8;;\:]8;id=861168;file:///mnt/project_rlinf/jlchen/code/UniVLA/prismatic/vla/latent_vla_model.py#476\476]8;;\
#                           `/mnt/project_rlinf/jlchen/code/UniVLA/vla_scripts/world_vla_log/
#                           0121_121439+checkpoints+libero_object_no_noops+lr-0.0001+frzVis+f
#                           rzLLM+unfrzLast4+frzEmb--finetune_libero_all_no_future_no_hist/ch
#                           eckpoints/step-005000`（HF from_pretrained, generic）
# ...
